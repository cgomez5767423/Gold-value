# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Price changes in metals as it relates to fiat curreny
import pandas

# %%
df = pandas.read_csv("alum_gold_nickel_silver_uran_price_changes.csv")

# %%
df = pd.read_csv ("alum_gold_nickel_silver_uran_price_changes.csv")

# %%
df.head(360)
# Out:
#        Year Month  Price_alum Price_gold  Price_nickel  Price_silver  \
# 0    1992.0   Feb     1266.83     353.91       7861.90          4.15
# 1    1992.0   Mar     1280.47     344.34       7417.70          4.11
# 2    1992.0   Apr     1317.05     338.62       7420.60          4.05
# 3    1992.0   May     1306.79     337.24       7326.80          4.07
# 4    1992.0   Jun     1275.55     340.81       7192.80          4.06
# ..      ...   ...         ...        ...           ...           ...
# 355  2021.0   Sep     2834.56    1775.14      19376.88         23.19
# 356  2021.0   Oct     2934.39    1776.85      19362.39         23.41
# 357  2021.0   Nov     2636.45    1821.76      19932.86         24.18
# 358  2021.0   Dec     2695.53    1790.43      20015.55         22.53
# 359  2022.0   Jan     3005.98    1816.02      22355.40         23.16
#
#      Price_uran  Inflation_rate  Price_alum_infl  Price_gold_infl  \
# 0          7.90           89.59      2401.782997       670.977969
# ...

# %%
df.info(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               360 non-null    float64
#  1   Month              360 non-null    object
#  2   Price_alum         360 non-null    float64
#  3   Price_gold         361 non-null    object
#  4   Price_nickel       360 non-null    float64
#  5   Price_silver       360 non-null    float64
#  6   Price_uran         358 non-null    float64
#  7   Inflation_rate     347 non-null    float64
#  8   Price_alum_infl    359 non-null    float64
#  9   Price_gold_infl    359 non-null    float64
#  10  Price_nickel_infl  359 non-null    float64
#  11  Price_silver_infl  359 non-null    float64
#  12  Price_uran_infl    359 non-null    float64
# dtypes: float64(11), object(2)
# memory usage: 104.0+ MB

# %%
df.describe()
# Out:
#               Year   Price_alum  Price_nickel  Price_silver  Price_uran  \
# count   360.000000   360.000000    360.000000    360.000000  358.000000
# mean   2006.583333  1803.781972  13176.930750     12.852333   28.394469
# std       8.671906   442.612174   7682.024357      8.716378   21.385594
# min    1992.000000  1039.810000   3871.930000      3.650000    7.100000
# 25%    1999.000000  1466.685000   7320.405000      5.077500   10.492500
# 50%    2007.000000  1738.535000  11663.550000     12.350000   24.560000
# 75%    2014.000000  2042.630000  16749.457500     17.585000   39.657500
# max    2022.000000  3071.240000  52179.050000     42.700000  136.220000
#
#        Inflation_rate  Price_alum_infl  Price_gold_infl  Price_nickel_infl  \
# count      347.000000       359.000000       359.000000         359.000000
# mean        36.320029      2358.265633      1012.044899       16597.831534
# std         27.062804       450.172012       504.858385        8580.000084
# ...

# %%
df.isnull() .sum()/ dataset.shape [0]*100
# Out:
# Year                 99.965668
# Month                99.965668
# Price_alum           99.965668
# Price_gold           99.965572
# Price_nickel         99.965668
# Price_silver         99.965668
# Price_uran           99.965858
# Inflation_rate       99.966907
# Price_alum_infl      99.965763
# Price_gold_infl      99.965763
# Price_nickel_infl    99.965763
# Price_silver_infl    99.965763
# Price_uran_infl      99.965763
# dtype: float64

# %%
df.tail()
# Out:
#          Year Month  Price_alum Price_gold  Price_nickel  Price_silver  \
# 1048570   NaN   NaN         NaN        NaN           NaN           NaN
# 1048571   NaN   NaN         NaN        NaN           NaN           NaN
# 1048572   NaN   NaN         NaN        NaN           NaN           NaN
# 1048573   NaN   NaN         NaN        NaN           NaN           NaN
# 1048574   NaN   NaN         NaN      Price           NaN           NaN
#
#          Price_uran  Inflation_rate  Price_alum_infl  Price_gold_infl  \
# 1048570         NaN             NaN              NaN              NaN
# 1048571         NaN             NaN              NaN              NaN
# 1048572         NaN             NaN              NaN              NaN
# 1048573         NaN             NaN              NaN              NaN
# 1048574         NaN             NaN              NaN              NaN
#
#          Price_nickel_infl  Price_silver_infl  Price_uran_infl
# ...

# %%
df.duplicated().sum()
# Out:
# 1048213

# %%
dataset.describe(include="object")
# Out:
#        Month  Price_gold
# count    360      361.00
# unique    12      360.00
# top      Feb      383.14
# freq      30        2.00

# %%
import warnings
warnings.filterwarnings("ignore")
for i in dataset.select_dtypes(include="number").columns:
    sns.histplot(data=dataset,x=i)
    plt.show ()

# %%
for i in ['Year', 'Price_alum', 'Price_nickel', 'Price_silver', 'Price_uran',
       'Inflation_rate', 'Price_alum_infl', 'Price_gold_infl',
       'Price_nickel_infl', 'Price_silver_infl', 'Price_uran_infl']:

    sns.scatterplot (data=df,x=i,y='Inflation_rate')

    plt.show()

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Year', 'Price_alum', 'Price_nickel', 'Price_silver', 'Price_uran',
#        'Inflation_rate', 'Price_alum_infl', 'Price_gold_infl',
#        'Price_nickel_infl', 'Price_silver_infl', 'Price_uran_infl'],
#       dtype='object')

# %%
df.select_dtypes(include="number").corr()
# Out:
#                        Year  Price_alum  Price_nickel  Price_silver  \
# Year               1.000000    0.507016      0.438791      0.757101
# Price_alum         0.507016    1.000000      0.846201      0.600575
# Price_nickel       0.438791    0.846201      1.000000      0.555421
# Price_silver       0.757101    0.600575      0.555421      1.000000
# Price_uran         0.444834    0.763440      0.887441      0.583302
# Inflation_rate    -0.984684   -0.591238     -0.536963     -0.766215
# Price_alum_infl   -0.301173    0.623847      0.504717      0.014051
# Price_gold_infl    0.819101    0.468812      0.424994      0.937948
# Price_nickel_infl  0.219447    0.764883      0.962615      0.398579
# Price_silver_infl  0.654117    0.573120      0.546885      0.986220
# Price_uran_infl    0.300737    0.691783      0.850095      0.477435
#
#                    Price_uran  Inflation_rate  Price_alum_infl  \
# Year                 0.444834       -0.984684        -0.301173
# ...
